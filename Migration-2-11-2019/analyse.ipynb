# %% [markdown]
# ### Data Analysis

# %%
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open("data/database/sample.json", 'r') as f:
    sample = json.load(f)

# %%
len(sample)
# Out:
# 1000

# %%
for item in sample:
    for item in list(item.keys()):
        print(item)
    break
# Out:
# ID
# age
# gender
# profession
# interest
# home_address
# foreign_address
# date_out
# date_return
# fund2invest
# remittance
# travell
# social_work
# personal_view

# %%
DF = pd.DataFrame(sample)

# %%
DF = DF.set_index('ID')

# %%
DF.head(3)
# Out:
#             age    date_out date_return  \
# ID
# 3LJJB6B924   29   2014.9.21   2022.3.16
# 5S5MI9J6K4   44  2011.10.26   2020.3.15
# 3CO6495O5G   38   2016.8.27  2023.10.13
#
#                                               foreign_address  \
# ID
# 3LJJB6B924  {'country': 'Costa-Rica', 'ID': 'CR', 'lat': '...
# 5S5MI9J6K4  {'country': 'Cook-Islands', 'ID': 'CK', 'lat':...
# 3CO6495O5G  {'country': 'Kenya', 'ID': 'KE', 'lat': '-0.02...
#
#                                                   fund2invest  gender  \
# ID
# 3LJJB6B924  {'invetsment sector': '3%', 'tourism and hospi...  female
# 5S5MI9J6K4  {'invetsment sector': '10%', 'tourism and hosp...  female
# 3CO6495O5G  {'invetsment sector': '6%', 'tourism and hospi...  female
#
#                                                  home_address interest  \
# ID
# 3LJJB6B924  {'province': 'PN6', 'district': 'Jajarkot', 'M...      art
# 5S5MI9J6K4  {'province': 'PN1', 'district': 'Sunsari', 'MC...    novel
# 3CO6495O5G  {'province': 'PN1', 'district': 'Solukhumbu', ...    music
#
#                                                 personal_view  \
# ID
# 3LJJB6B924  [Kathmandu Metropolitan City’s undying infatua...
# 5S5MI9J6K4  [Granted, these initiatives are nothing new—th...
# 3CO6495O5G  [In response to the pressure, Parliament devis...
#
#                                                    profession  \
# ID
# 3LJJB6B924  {'major': 'Life, Physical, and Social Science ...
# 5S5MI9J6K4  {'major': 'Military Specific Occupations', 'br...
# 3CO6495O5G  {'major': 'Installation, Maintenance, and Repa...
#
#                                                    remittance  \
# ID
# 3LJJB6B924  [{'month': 4, 'amount': 981}, {'month': 11, 'a...
# 5S5MI9J6K4  [{'month': 11, 'amount': 962}, {'month': 10, '...
# 3CO6495O5G  [{'month': 4, 'amount': 306}, {'month': 8, 'am...
#
#                                                   social_work  \
# ID
# 3LJJB6B924  [{'date': '2015.4.2', 'work': 'work against hu...
# 5S5MI9J6K4  [{'date': '2005.1.3', 'work': 'resolving the c...
# 3CO6495O5G  [{'date': '2017.9.13', 'work': 'work against h...
#
#                                                       travell
# ID
# 3LJJB6B924  [{'date': '2017.5.8', 'place': {'country': 'Mo...
# 5S5MI9J6K4  [{'date': '2010.4.11', 'place': {'country': 'V...
# 3CO6495O5G  [{'date': '2010.10.19', 'place': {'country': '...

# %% [markdown]
# ### Data Processing

# %% [markdown]
# 1. Drop views
# 2. Seperate home address [PN,District,MCP,Ward]
# 3. Seperate Foreign address [country,lat,long,city]
# 4. Use lambda function $1000 = $1K
# 5. Create new column [month] with total month duration between data out-date return
# 6.

# %% [markdown]
# #### Data Exploration

# %% [markdown]
# 1. Age distribution ?
# 2. Gender and age - correlation?
# 3. County- gender ? Country- age ?
# 4. Histogram, bar-plot, ven-diagram ?

# %% [markdown]
# #### Data modeling - Machine lerning ( Scikit-learn)

# %% [markdown]
# 1. Linear-regression,
# 2. Classifier

# %% [markdown]
# #### Data Visualization ( matplotlib.pyplot, seaborn, Bokeh, plotly(Python-API)) (D3.JS, chart.js)

# %% [markdown]
# 1. Plot generation

# %% [markdown]
# ----------

# %%
Data = []
k = 0
for item in sample:
    #print(item.values()) 
    ID = item['ID']
    age = item['age']
    gender = item['gender']
    country = item['foreign_address']['country']
    province = item['home_address']['province']
    district = item['home_address']['district']
    lat = item['foreign_address']['lat']
    lon = item['foreign_address']['lon']
    interest = item['interest']
    profession = item['profession']['branch']
    income = 0
    for t in item['remittance']:
        income = income+t['amount']
        
    
    Data.append({'ID': ID,\
                 "age":age,\
                 "gender":gender,\
                 "country": country,\
                 "lat": lat,\
                 "lon":lon,\
                 "province":province,\
                 "district": district,\
                 "interest": interest,\
                 "profession": profession,\
                 "income": income})

# %%
DF = pd.DataFrame(Data)
DF = DF.set_index("ID")
DF.head()
# Out:
#             age       country    district  gender  income interest  \
# ID
# 3LJJB6B924   29    Costa-Rica    Jajarkot  female    3180      art
# 5S5MI9J6K4   44  Cook-Islands     Sunsari  female    3410    novel
# 3CO6495O5G   38         Kenya  Solukhumbu  female    2145    music
# K35G0P9M02   43     Venezuela       Palpa    male    2963  farming
# 5X85I310N0   41         Malta   Terhathum  female    2735   stocks
#
#                    lat          lon  \
# ID
# 3LJJB6B924    9.748917   -83.753428
# 5S5MI9J6K4  -21.236736  -159.777671
# 3CO6495O5G   -0.023559    37.906193
# K35G0P9M02     6.42375    -66.58973
# 5X85I310N0   35.937496    14.375416
#
#                                                    profession province
# ID
# 3LJJB6B924                 Zoologists and Wildlife Biologists      PN6
# 5S5MI9J6K4  Military Enlisted Tactical Operations and Air/...      PN1
# 3CO6495O5G            Maintenance and Repair Workers, General      PN1
# K35G0P9M02                          Tree Trimmers and Pruners      PN5
# 5X85I310N0                                            Fallers      PN1

# %%
# %matplotlib inline
Country = DF.groupby('country').count()['age']
df = pd.DataFrame(Country)
df = df.sort_values('age')
df[0:20].plot.barh(figsize = [15,10])

# %%
# %matplotlib inline
sns.set()
Country = DF.groupby('profession').count()['age']
df = pd.DataFrame(Country)
#df = df.sort_values('age')
df[0:50].plot.barh(figsize = [15,25])

# %%
plt.figure(figsize = (16,21))
sns.set(color_codes=True)
sns.factorplot("gender", col="province", data=DF, 
               hue='age', kind="count", col_wrap=2);

# %%
plt.figure(figsize = (15,21))
sns.jointplot(x="age", y="income", data=DF,size=15,kind = 'reg');
