# %% [markdown]
# ## A Random Person

# %%
import json as json
import random as random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from generator.person import *

# %%
with open("data/world/world.json", 'r') as f1:
    world = json.load(f1)

# %%
with open("data/nepal/NepalG.json", 'r') as f2:
    nepal = json.load(f2)

# %%
with open("data/professions/profession.json", 'r') as f3:
    prof = json.load(f3)

# %%
with open("data/views/views.json", 'r') as f4:
    views = json.load(f4)

# %%
with open("data/interest/personal.json", 'r') as f5:
    personal = json.load(f5)

# %%
with open("data/interest/interest.json", 'r') as f6:
    interest = json.load(f6)

# %%
with open("data/interest/socialwork.json", 'r') as f7:
    socialwork = json.load(f7)

# %%
Data = []
for k in range(2500):
    P = Person()
    P.set_ID()
    P.set_age()
    P.set_home_address(nepal)
    P.set_foreign_address(world)
    P.set_profession(prof) 
    P.set_date_out()
    P.set_date_return()
    P.set_fund2invest(interest)
    P.set_personal_view(views)
    P.set_gender()
    P.set_interest(personal)
    P.set_remittance()
    P.set_travell(world)
    P.set_social_work(socialwork)

    Data.append({"ID": P.ID,\
                 "age" : P.age,\
                 "gender" : P.gender,\
                 "profession": P.profession,\
                 "interest": P.interest,\
                 "home_address" : P.home_address,\
                 "foreign_address": P.foreign_address,\
                 "date_out": P.date_out,\
                 "date_return":P.date_return,\
                 "fund2invest":P.fund2invest,\
                 "remittance":P.remittance,\
                 "travell":P.travell,\
                 "social_work":P.social_work,\
                 "personal_view":P.personal_view})

# %%
Data[0:10]
# Out:
# [{'ID': 'TZ89CK45CP',
#   'age': 44,
#   'gender': 'female',
#   'profession': {'major': 'Life, Physical, and Social Science Occupations',
#    'branch': 'Conservation Scientists'},
#   'interest': 'travel',
#   'home_address': {'province': 'PN2',
#    'district': 'Saptari',
#    'MCP': 'Surunga MCP',
#    'ward': 'Ward 10'},
#   'foreign_address': {'country': 'Seychelles',
#    'ID': 'SC',
#    'lat': '-4.679574',
#    'lon': '55.491977',
#    'city': 'VICTORIA'},
#   'date_out': '2018.2.26',
#   'date_return': '2019.1.13',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '6%',
#    'animal husbandary': '1%',
#    'infrastructure': '7%',
#    'cottage industries': '3%',
#    'personal service business': '1%',
#    'retail business': '10%',
#    'consultancy service': '5%',
#    'alternative energy': '10%',
#    'agriculture': '8%',
#    'total_fund': 6709},
#   'remittance': [{'month': 10, 'amount': 676},
#    {'month': 4, 'amount': 443},
#    {'month': 11, 'amount': 130},
#    {'month': 4, 'amount': 529}],
#   'travell': [{'date': '2016.3.27',
#     'place': {'country': 'Tanzania', 'city': 'A'}},
#    {'date': '2015.11.18', 'place': {'country': 'Eritrea', 'city': 'ASMARA'}},
#    {'date': '2011.12.13',
#     'place': {'country': 'Turkmenistan', 'city': 'ASHKHABAD'}},
#    {'date': '2010.12.3',
#     'place': {'country': 'Zimbabwe', 'city': 'Chitungwiza'}}],
#   'social_work': [{'date': '2001.5.2', 'work': 'donation for school'},
#    {'date': '2002.6.16', 'work': 'help for disable person'},
#    {'date': '2003.3.16', 'work': 'work for physically disable person'}],
#   'personal_view': ['A day after the Panama Papers were exposed in April 2016, the Department of Money Laundering Investigation promised it would ‘begin a probe’ after calling a meeting of key stakeholders including the Financial Information Unit of Nepal Rastra Bank, the Department of Revenue Investigation and the Nepal Police. Following the meeting, the head of the Department of Money Laundering Investigation promised to adopt a ‘risk-based supervision system’ and claimed that the Financial Information Unit and the Central Investigation Bureau of the Nepal Police would ‘conduct an investigation’. As recent revelations have indicated, the investigations reaped minimal results in the last two years.']},
#  {'ID': 'D3G4EILJ48',
#   'age': 49,
#   'gender': 'female',
#   'profession': {'major': 'Computer and Mathematical Occupations',
#    'branch': 'Software Quality Assurance Analysts and Testers'},
#   'interest': 'teaching',
#   'home_address': {'province': 'PN5',
#    'district': 'Arghakhanchi',
#    'MCP': 'Bhumikasthan MCP',
#    'ward': 'Ward 8'},
#   'foreign_address': {'country': 'Norfolk-Island',
#    'ID': 'NF',
#    'lat': '-29.040835',
#    'lon': '167.954712',
#    'city': 'N'},
#   'date_out': '2010.10.7',
#   'date_return': '2020.6.1',
#   'fund2invest': {'invetsment sector': '10%',
#    'tourism and hospitality': '2%',
#    'animal husbandary': '5%',
#    'infrastructure': '7%',
#    'cottage industries': '4%',
#    'personal service business': '4%',
#    'retail business': '10%',
#    'consultancy service': '2%',
#    'alternative energy': '7%',
#    'agriculture': '5%',
#    'total_fund': 2542},
#   'remittance': [{'month': 2, 'amount': 398},
#    {'month': 7, 'amount': 628},
#    {'month': 9, 'amount': 973},
#    {'month': 6, 'amount': 609},
#    {'month': 11, 'amount': 416},
#    {'month': 10, 'amount': 833}],
#   'travell': [{'date': '2019.1.21',
#     'place': {'country': 'Rwanda', 'city': 'Butare'}},
#    {'date': '2015.11.11', 'place': {'country': 'Tuvalu', 'city': 'FUNAFUTI'}},
#    {'date': '2014.7.11',
#     'place': {'country': 'Antigua-and-Barbuda', 'city': 'A'}}],
#   'social_work': [{'date': '2003.2.18', 'work': 'charity events'},
#    {'date': '2012.11.10', 'work': 'resettlement for groups'},
#    {'date': '2002.9.21', 'work': 'security plan'}],
#   'personal_view': ['In response to the pressure, Parliament devised several legislative measures to monitor money laundering—including the endorsement of the Anti-Money Laundering Act and the establishment of the Department of Money Laundering Investigation in 2011. After being removed from the FATF’s watch list in June 2011, the government seemingly forgot about its commitment to the cause. In the seven years of existence, the Department of Money Laundering Investigation has filed a meagre 40 money laundering cases at the Special Court, and most of them against petty or more low-profile violators. In the past three years, only 10 cases were filed, most of them related to minor charges. This points to a dismal conclusion: Issues related to money laundering only seem to matter when global monitoring organisations intervene']},
#  {'ID': 'LU4G6L54GG',
#   'age': 46,
#   'gender': 'male',
#   'profession': {'major': 'Business and Financial Operations Occupations',
#    'branch': 'Compensation, Benefits, and Job Analysis Specialists'},
#   'interest': 'art',
#   'home_address': {'province': 'PN6',
#    'district': 'Humla',
#    'MCP': 'Namkha RM',
#    'ward': 'Ward 4'},
#   'foreign_address': {'country': 'Saint-Lucia',
#    'ID': 'LC',
#    'lat': '13.909444',
#    'lon': '-60.978893',
#    'city': 'A'},
#   'date_out': '2019.5.17',
#   'date_return': '2033.9.8',
#   'fund2invest': {'invetsment sector': '9%',
#    'tourism and hospitality': '9%',
#    'animal husbandary': '9%',
#    'infrastructure': '5%',
#    'cottage industries': '5%',
#    'personal service business': '7%',
#    'retail business': '10%',
#    'consultancy service': '2%',
#    'alternative energy': '2%',
#    'agriculture': '5%',
#    'total_fund': 9837},
#   'remittance': [{'month': 8, 'amount': 472},
#    {'month': 4, 'amount': 129},
#    {'month': 6, 'amount': 228}],
#   'travell': [{'date': '2014.4.24',
#     'place': {'country': 'Czech-Republic', 'city': 'A'}},
#    {'date': '2019.11.19',
#     'place': {'country': 'Guatemala', 'city': 'Villa Nueva'}}],
#   'social_work': [{'date': '2017.10.1', 'work': 'helping old people'},
#    {'date': '2010.6.2', 'work': 'education programmee for infant and mother'}],
#   'personal_view': ['To add to the erroneous logic, Kathmandu Metropolitan City also recently issued a ‘crackdown on litter-bugs’—if officials find people throwing any form of waste on the city’s roads, they will be fined up to Rs.5,000. These fines overlook a glaring reality: dustbins are scarce. Rather than spending a gross amount of money on a few ‘smart dustbins’, why not invest money in ensuring that regular old dustbins are available at every street corner? Or why not redirect attention towards working with the central government to battle the city’s enduring waste management crisis? These steps would address much more than a 6-lakh-worth-of-a-dustbin ever could.']},
#  {'ID': 'PPTYX7GV58',
#   'age': 31,
#   'gender': 'female',
#   'profession': {'major': 'Healthcare Support Occupations',
#    'branch': 'Personal Care Aides'},
#   'interest': 'business',
#   'home_address': {'province': 'PN2',
#    'district': 'Bara',
#    'MCP': 'Jitpur Simara S-MCP',
#    'ward': 'Ward 13'},
#   'foreign_address': {'country': 'Belarus',
#    'ID': 'BY',
#    'lat': '53.709807',
#    'lon': '27.953389',
#    'city': 'Orsha'},
#   'date_out': '2012.4.3',
#   'date_return': '2032.2.24',
#   'fund2invest': {'invetsment sector': '8%',
#    'tourism and hospitality': '4%',
#    'animal husbandary': '3%',
#    'infrastructure': '6%',
#    'cottage industries': '6%',
#    'personal service business': '2%',
#    'retail business': '7%',
#    'consultancy service': '7%',
#    'alternative energy': '5%',
#    'agriculture': '1%',
#    'total_fund': 8186},
#   'remittance': [{'month': 4, 'amount': 866},
#    {'month': 1, 'amount': 882},
#    {'month': 11, 'amount': 130},
#    {'month': 6, 'amount': 610},
#    {'month': 2, 'amount': 913}],
#   'travell': [{'date': '2018.1.28',
#     'place': {'country': 'Netherlands-Antilles', 'city': 'N'}},
#    {'date': '2017.6.10', 'place': {'country': 'Timor-Leste', 'city': 'DILI'}},
#    {'date': '2011.6.18', 'place': {'country': 'Senegal', 'city': 'Thiès'}},
#    {'date': '2012.1.13',
#     'place': {'country': 'Tajikistan', 'city': 'Khujand'}},
#    {'date': '2015.2.27', 'place': {'country': 'Isle-of-Man', 'city': 'A'}}],
#   'social_work': [{'date': '2008.2.11', 'work': 'medical camp'},
#    {'date': '2004.3.14', 'work': 'small industries for women'},
#    {'date': '2006.11.1', 'work': 'culture saving programme'},
#    {'date': '2001.9.1', 'work': 'donation for school'}],
#   'personal_view': ['Yet, having said that, the companies cannot operate without taking responsibility for their actions. The terms and services page of both Tootle and Pathao mention that they are only ‘a technology company that does not provide or engage in transportation services’. It further mentions that ‘the company is not a transportation provider’. These statements make it easier for them to shirk responsibility. Also, it does not make them liable for the insurance of the rider or the passenger in case of an accident. As a service provider, ensuring the safety of customers should be any company’s top priority—especially in the business of transportation.']},
#  {'ID': 'Z3X1819EMU',
#   'age': 26,
#   'gender': 'male',
#   'profession': {'major': 'Community and Social Service Occupations',
#    'branch': 'Marriage and Family Therapists'},
#   'interest': 'history',
#   'home_address': {'province': 'PN4',
#    'district': 'Kaski',
#    'MCP': 'Machhapuchhre RM',
#    'ward': 'Ward 6'},
#   'foreign_address': {'country': 'Botswana',
#    'ID': 'BW',
#    'lat': '-22.328474',
#    'lon': '24.684866',
#    'city': 'GABORONE'},
#   'date_out': '2010.10.14',
#   'date_return': '2034.1.3',
#   'fund2invest': {'invetsment sector': '6%',
#    'tourism and hospitality': '3%',
#    'animal husbandary': '6%',
#    'infrastructure': '8%',
#    'cottage industries': '1%',
#    'personal service business': '2%',
#    'retail business': '3%',
#    'consultancy service': '6%',
#    'alternative energy': '7%',
#    'agriculture': '1%',
#    'total_fund': 3087},
#   'remittance': [{'month': 2, 'amount': 849},
#    {'month': 6, 'amount': 645},
#    {'month': 2, 'amount': 282},
#    {'month': 3, 'amount': 200}],
#   'travell': [{'date': '2013.4.13',
#     'place': {'country': 'Australia', 'city': 'Adelaide'}},
#    {'date': '2014.5.24', 'place': {'country': 'French-Guiana', 'city': 'A'}},
#    {'date': '2012.2.10', 'place': {'country': 'Fiji', 'city': 'SUVA'}},
#    {'date': '2010.6.7',
#     'place': {'country': 'Saint-Vincent-and-the-Grenadines', 'city': 'N'}},
#    {'date': '2018.1.23', 'place': {'country': 'Tuvalu', 'city': 'FUNAFUTI'}}],
#   'social_work': [{'date': '2002.5.3', 'work': 'child orphanage'},
#    {'date': '2003.11.19', 'work': 'security plan'}],
#   'personal_view': ['To add to the erroneous logic, Kathmandu Metropolitan City also recently issued a ‘crackdown on litter-bugs’—if officials find people throwing any form of waste on the city’s roads, they will be fined up to Rs.5,000. These fines overlook a glaring reality: dustbins are scarce. Rather than spending a gross amount of money on a few ‘smart dustbins’, why not invest money in ensuring that regular old dustbins are available at every street corner? Or why not redirect attention towards working with the central government to battle the city’s enduring waste management crisis? These steps would address much more than a 6-lakh-worth-of-a-dustbin ever could.']},
#  {'ID': 'R67H298915',
#   'age': 26,
#   'gender': 'female',
#   'profession': {'major': 'Installation, Maintenance, and Repair Occupations',
#    'branch': 'Heating, Air Conditioning, and Refrigeration Mechanics and Installers'},
#   'interest': 'farming',
#   'home_address': {'province': 'PN7',
#    'district': 'Baitadi',
#    'MCP': 'Purchaudi MCP',
#    'ward': 'Ward 2'},
#   'foreign_address': {'country': 'Belgium',
#    'ID': 'BE',
#    'lat': '50.503887',
#    'lon': '4.469936',
#    'city': 'Namur'},
#   'date_out': '2019.10.8',
#   'date_return': '2021.8.15',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '6%',
#    'animal husbandary': '7%',
#    'infrastructure': '5%',
#    'cottage industries': '4%',
#    'personal service business': '1%',
#    'retail business': '1%',
#    'consultancy service': '10%',
#    'alternative energy': '8%',
#    'agriculture': '10%',
#    'total_fund': 9769},
#   'remittance': [{'month': 4, 'amount': 479},
#    {'month': 4, 'amount': 477},
#    {'month': 9, 'amount': 356},
#    {'month': 4, 'amount': 684}],
#   'travell': [{'date': '2013.12.26',
#     'place': {'country': 'Saint-Vincent-and-the-Grenadines', 'city': 'A'}},
#    {'date': '2012.3.28', 'place': {'country': 'Austria', 'city': 'Graz'}},
#    {'date': '2011.10.12', 'place': {'country': 'Georgia', 'city': 'TBILISI'}},
#    {'date': '2014.5.18', 'place': {'country': 'Guinea', 'city': 'Kankan'}}],
#   'social_work': [{'date': '2005.4.24', 'work': 'helping the homeless'},
#    {'date': '2006.2.23', 'work': 'helping the homeless'},
#    {'date': '2018.7.28', 'work': 'awareness programme for maternal women'},
#    {'date': '2012.3.9', 'work': 'education programmee for infant and mother'},
#    {'date': '2009.9.19', 'work': 'work for physically disable person'}],
#   'personal_view': ['In response to the pressure, Parliament devised several legislative measures to monitor money laundering—including the endorsement of the Anti-Money Laundering Act and the establishment of the Department of Money Laundering Investigation in 2011. After being removed from the FATF’s watch list in June 2011, the government seemingly forgot about its commitment to the cause. In the seven years of existence, the Department of Money Laundering Investigation has filed a meagre 40 money laundering cases at the Special Court, and most of them against petty or more low-profile violators. In the past three years, only 10 cases were filed, most of them related to minor charges. This points to a dismal conclusion: Issues related to money laundering only seem to matter when global monitoring organisations intervene']},
#  {'ID': 'KI64XFO36N',
#   'age': 30,
#   'gender': 'female',
#   'profession': {'major': 'Military Specific Occupations',
#    'branch': 'FirstLine Supervisors of Air Crew Members'},
#   'interest': 'art',
#   'home_address': {'province': 'PN4',
#    'district': 'Kaski',
#    'MCP': 'Annapurna RM',
#    'ward': 'Ward 2'},
#   'foreign_address': {'country': 'Kiribati',
#    'ID': 'KI',
#    'lat': '-3.370417',
#    'lon': '-168.734039',
#    'city': 'TARAWA'},
#   'date_out': '2010.5.5',
#   'date_return': '2021.10.23',
#   'fund2invest': {'invetsment sector': '6%',
#    'tourism and hospitality': '8%',
#    'animal husbandary': '2%',
#    'infrastructure': '6%',
#    'cottage industries': '4%',
#    'personal service business': '10%',
#    'retail business': '3%',
#    'consultancy service': '5%',
#    'alternative energy': '3%',
#    'agriculture': '4%',
#    'total_fund': 1778},
#   'remittance': [{'month': 2, 'amount': 600},
#    {'month': 7, 'amount': 231},
#    {'month': 6, 'amount': 920},
#    {'month': 10, 'amount': 992},
#    {'month': 9, 'amount': 840},
#    {'month': 8, 'amount': 211}],
#   'travell': [{'date': '2012.2.21',
#     'place': {'country': 'Cape-Verde', 'city': 'A'}},
#    {'date': '2012.5.7', 'place': {'country': 'Cyprus', 'city': 'N'}},
#    {'date': '2017.5.25', 'place': {'country': 'Guinea', 'city': 'Siguiri'}},
#    {'date': '2018.10.2', 'place': {'country': 'Italy', 'city': 'Siracusa'}},
#    {'date': '2010.12.20', 'place': {'country': 'Tunisia', 'city': 'TUNIS'}}],
#   'social_work': [{'date': '2017.9.17', 'work': 'building temples'},
#    {'date': '2016.10.9', 'work': 'pollution control'},
#    {'date': '2008.11.19', 'work': 'community sanitation'},
#    {'date': '2018.7.24', 'work': 'community forest'}],
#   'personal_view': ['Granted, these initiatives are nothing new—they’ve been packaged in various forms and promises throughout the years. But they show that Kathmandu Metropolitan City is overlooking what should be at the heart of any ‘smart’ city initiative: empowered citizens and sustainable solutions. Kathmandu needs more than glossy, quick fixes that can be added to mayoral repertoires. The tendency to focus on the temporary is exemplified everywhere—from perpetually defunct broomer machines that blow dust in the air in their attempt to ‘clean Kathmandu’s roads’ to ‘smart dustbins’ surrounded by litter. Rather than pursuing the glitzy, KMC should prioritise on ensuring that basic necessities—like regular old dustbins and functioning sanitised toilets—serve their intended purposes and are available to all.']},
#  {'ID': '8AYEV53J37',
#   'age': 41,
#   'gender': 'female',
#   'profession': {'major': 'Sales and Related Occupations',
#    'branch': 'Insurance Sales Agents'},
#   'interest': 'social work',
#   'home_address': {'province': 'PN1',
#    'district': 'Jhapa',
#    'MCP': 'Kanchankawal RM',
#    'ward': 'Ward 3'},
#   'foreign_address': {'country': 'Isle-of-Man',
#    'ID': 'IM',
#    'lat': '54.236107',
#    'lon': '-4.548056',
#    'city': 'A'},
#   'date_out': '2011.6.3',
#   'date_return': '2033.4.28',
#   'fund2invest': {'invetsment sector': '6%',
#    'tourism and hospitality': '6%',
#    'animal husbandary': '6%',
#    'infrastructure': '1%',
#    'cottage industries': '2%',
#    'personal service business': '9%',
#    'retail business': '4%',
#    'consultancy service': '2%',
#    'alternative energy': '6%',
#    'agriculture': '3%',
#    'total_fund': 8349},
#   'remittance': [{'month': 2, 'amount': 377},
#    {'month': 1, 'amount': 396},
#    {'month': 7, 'amount': 688},
#    {'month': 4, 'amount': 602},
#    {'month': 5, 'amount': 922},
#    {'month': 1, 'amount': 876}],
#   'travell': [{'date': '2015.9.21',
#     'place': {'country': 'Guinea-Bissau', 'city': 'BISSAU'}},
#    {'date': '2015.9.26', 'place': {'country': 'Cayman-Islands', 'city': 'N'}},
#    {'date': '2019.12.5', 'place': {'country': 'Isle-of-Man', 'city': 'N'}},
#    {'date': '2015.7.4', 'place': {'country': 'Saudi-Arabia', 'city': 'N'}},
#    {'date': '2016.9.11', 'place': {'country': 'Burkina-Faso', 'city': 'N'}}],
#   'social_work': [{'date': '2003.3.1',
#     'work': 'awareness programme for maternal women'},
#    {'date': '2001.9.8', 'work': 'work for physically disable person'},
#    {'date': '2015.11.6', 'work': 'work for physically disable person'}],
#   'personal_view': ['While all parties involved in the construction process have contributed to the current fiasco, one lesson is especially poignant as stakeholders take the next necessary steps to identify a new contractor: more thoughtful deliberation must factor into procurement decisions. A number of factors—including corruption, mismanagement, deviation from contract promises, sluggish cash flow, and a circular bout of finger pointing—has played into the current Melamchi saga. But tussles between contractors and government officials, often manifesting in contract terminations, have featured heavily in these delays.']},
#  {'ID': '4TDN4A2352',
#   'age': 48,
#   'gender': 'male',
#   'profession': {'major': 'Legal Occupations',
#    'branch': 'Legal Support Workers, All Other'},
#   'interest': 'business',
#   'home_address': {'province': 'PN5',
#    'district': 'Arghakhanchi',
#    'MCP': 'Shit Ganga MCP',
#    'ward': 'Ward 4'},
#   'foreign_address': {'country': 'Haiti',
#    'ID': 'HT',
#    'lat': '18.971187',
#    'lon': '-72.285215',
#    'city': 'N'},
#   'date_out': '2014.10.6',
#   'date_return': '2024.11.21',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '9%',
#    'animal husbandary': '1%',
#    'infrastructure': '5%',
#    'cottage industries': '6%',
#    'personal service business': '6%',
#    'retail business': '9%',
#    'consultancy service': '7%',
#    'alternative energy': '10%',
#    'agriculture': '6%',
#    'total_fund': 3815},
#   'remittance': [{'month': 9, 'amount': 188},
#    {'month': 2, 'amount': 769},
#    {'month': 10, 'amount': 451},
#    {'month': 4, 'amount': 126},
#    {'month': 10, 'amount': 947},
#    {'month': 4, 'amount': 244}],
#   'travell': [{'date': '2016.3.19',
#     'place': {'country': 'Niger', 'city': 'Tahoua'}},
#    {'date': '2011.3.14', 'place': {'country': 'Micronesia', 'city': 'A'}},
#    {'date': '2019.8.3', 'place': {'country': 'Sweden', 'city': 'STOCKHOLM'}}],
#   'social_work': [{'date': '2007.7.3', 'work': 'trust for welfare'},
#    {'date': '2015.4.5', 'work': 'resolving the conflict'},
#    {'date': '2016.10.3', 'work': 'community forest'}],
#   'personal_view': ['In response to the pressure, Parliament devised several legislative measures to monitor money laundering—including the endorsement of the Anti-Money Laundering Act and the establishment of the Department of Money Laundering Investigation in 2011. After being removed from the FATF’s watch list in June 2011, the government seemingly forgot about its commitment to the cause. In the seven years of existence, the Department of Money Laundering Investigation has filed a meagre 40 money laundering cases at the Special Court, and most of them against petty or more low-profile violators. In the past three years, only 10 cases were filed, most of them related to minor charges. This points to a dismal conclusion: Issues related to money laundering only seem to matter when global monitoring organisations intervene']},
#  {'ID': 'VND1HQW7QR',
#   'age': 37,
#   'gender': 'female',
#   'profession': {'major': 'Architecture and Engineering Occupations',
#    'branch': 'Surveying and Mapping Technicians'},
#   'interest': 'travel',
#   'home_address': {'province': 'PN4',
#    'district': 'Gorkha',
#    'MCP': 'Chumanubri RM',
#    'ward': 'Ward 6'},
#   'foreign_address': {'country': 'Ghana',
#    'ID': 'GH',
#    'lat': '7.946527',
#    'lon': '-1.023194',
#    'city': 'Obuasi'},
#   'date_out': '2014.12.27',
#   'date_return': '2020.10.13',
#   'fund2invest': {'invetsment sector': '1%',
#    'tourism and hospitality': '8%',
#    'animal husbandary': '5%',
#    'infrastructure': '6%',
#    'cottage industries': '9%',
#    'personal service business': '1%',
#    'retail business': '8%',
#    'consultancy service': '2%',
#    'alternative energy': '5%',
#    'agriculture': '2%',
#    'total_fund': 1888},
#   'remittance': [{'month': 11, 'amount': 561},
#    {'month': 11, 'amount': 744},
#    {'month': 11, 'amount': 642},
#    {'month': 1, 'amount': 857},
#    {'month': 9, 'amount': 582},
#    {'month': 5, 'amount': 664}],
#   'travell': [{'date': '2011.2.8',
#     'place': {'country': 'Niger', 'city': 'Zinder'}},
#    {'date': '2017.12.13',
#     'place': {'country': 'Madagascar', 'city': 'Fianarantsoa'}},
#    {'date': '2015.4.9', 'place': {'country': 'Outlying-Islands', 'city': 'N'}},
#    {'date': '2019.12.6', 'place': {'country': 'El-Salvador', 'city': 'A'}},
#    {'date': '2011.11.11',
#     'place': {'country': 'Cameroon', 'city': 'Bertoua'}}],
#   'social_work': [{'date': '2001.3.15', 'work': 'creating employment'},
#    {'date': '2009.9.8', 'work': 'charity events'},
#    {'date': '2002.11.7', 'work': 'education programmee for infant and mother'},
#    {'date': '2018.11.8', 'work': 'community forest'}],
#   'personal_view': ['Around 30 years, over a dozen missed deadlines, and two terminated contracts since it was first announced, the Melamchi Water Supply Project hangs in limbo, once again. Following months of conflict with the Italian contractor Cooperativa Muratori e Cementisti di Ravenna (CMC), the government has now formally issued a letter of termination, causing further (and seemingly perpetual) delays to the national pride project. Granted, delays to the project stopped surprising people 20 years and over a dozen-missed deadlines ago, but the current fiasco warrants introspection, especially as officials claim that the project is only 5 percent shy of completion.']}]

# %%
with open("data/database/sample.json","w")as fw:
    json.dump(Data,fw)
